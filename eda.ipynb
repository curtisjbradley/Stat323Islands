# %%
from api.API import IslandsAPI
from api.tasks import *
from api.tasks import CHOCOLATE_DARK_99

api = IslandsAPI()

# %%
person = api.get_study_participants()[0]

# %%
person.get_task_results()
# Out:
# [Respiratory Rate 2 mins @ 13/378 22:10 - (20 breaths/min),
#  Banana 100 g @ 13/378 22:08 - (None),
#  Banana 100 g @ 13/378 22:07 - (None),
#  Banana 100 g @ 13/378 22:06 - (None),
#  Banana 100 g @ 13/378 22:00 - (None),
#  Banana 100 g @ 13/378 21:54 - (None),
#  Banana 100 g @ 13/378 21:53 - (None),
#  Banana 100 g @ 13/378 21:47 - (None),
#  Banana 100 g @ 13/378 21:34 - (None),
#  Aspirin 500 mg @ 13/378 21:14 - (None),
#  Husaam consented to be in your study @ 11/378 22:35 - (None)]

# %%
person.get_village()

# %%
import time

# %%
print(time.time_ns() // 1_000_000)
text = person.do_task(Task('breathing'))
text

# %%
split_lines = text.splitlines()

# %%
Task('banana').code

# %%
globals()
